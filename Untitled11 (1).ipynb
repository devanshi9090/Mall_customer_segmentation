# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

# %%
df = pd.read_csv('Mall_Customers.csv')

# %%
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1       0   19                  15                      39
# 1           2       0   21                  15                      81
# 2           3       1   20                  16                       6
# 3           4       1   23                  16                      77
# 4           5       1   31                  17                      40

# %%
df.corr()
# Out:
#                         CustomerID    Gender       Age  Annual Income (k$)  \
# CustomerID                1.000000 -0.057400 -0.026763            0.977548
# Gender                   -0.057400  1.000000 -0.060867           -0.056410
# Age                      -0.026763 -0.060867  1.000000           -0.012398
# Annual Income (k$)        0.977548 -0.056410 -0.012398            1.000000
# Spending Score (1-100)    0.013835  0.058109 -0.327227            0.009903
#
#                         Spending Score (1-100)
# CustomerID                            0.013835
# Gender                                0.058109
# Age                                  -0.327227
# Annual Income (k$)                    0.009903
# Spending Score (1-100)                1.000000

# %%
new_df = df.drop('CustomerID',axis = 1)

# %%
sns.heatmap(new_df.corr())
# Out:
# <AxesSubplot:>

# %%
#Distribution of Annnual Income
plt.figure(figsize=(10, 6))
sns.set(style = 'whitegrid')
sns.distplot(df['Annual Income (k$)'])
plt.title('Distribution of Annual Income (k$)', fontsize = 20)
plt.xlabel('Range of Annual Income (k$)')
plt.ylabel('Count')
# Out:
# D:\MIT\ANACONDA\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Count')

# %%
plt.figure(figsize=(10, 6))
sns.set(style = 'whitegrid')
sns.distplot(df['Age'])
plt.title('Distribution of Age', fontsize = 20)
plt.xlabel('Range of Age')
plt.ylabel('Count')
# Out:
# D:\MIT\ANACONDA\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Count')

# %%
plt.figure(figsize=(10, 6))
sns.set(style = 'whitegrid')
sns.distplot(df['Spending Score (1-100)'])
plt.title('Distribution of spending score', fontsize = 20)
plt.xlabel('Range of spending score')
plt.ylabel('Count')
# Out:
# D:\MIT\ANACONDA\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Count')

# %%
genders = df.Gender.value_counts()
sns.set_style("darkgrid")
plt.figure(figsize=(10,4))
sns.barplot(x=genders.index, y=genders.values)
plt.xlabel('Gender')
plt.ylabel('count')
plt.show()

# %%
genders = df.Gender.value_counts()

# %%
genders
# Out:
# 1    112
# 0     88
# Name: Gender, dtype: int64

# %%
plt.figure(figsize=(10,6)) #inserting the size of the plot.
sns.scatterplot(x = 'Age' , y = 'Annual Income (k$)' , hue="Gender",data = df,s = 100)
plt.xlabel('Age'), plt.ylabel('Annual Income (k$)') 
#checking the annual income as a function of age
plt.title('Age vs Annual Income w.r.t Gender')
plt.legend()
plt.show()

# %%
sns.histplot(data = df, x = "Age", y = "Annual Income (k$)",kde = True, hue = "Gender")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Annual Income (k$)'>

# %%
palette_color = seaborn.color_palette('bright')
  
# plotting data on chart
plt.pie(df.Age, df.AnnualIncome(k$), labels=keys, colors=palette_color, autopct='%.0f%%')
  
# displaying chart
plt.show()
# Out:
#   File "C:\Users\User\AppData\Local\Temp/ipykernel_13872/3769291405.py", line 4
#     plt.pie(df.Age, df.AnnualIncome(k$), labels=keys, colors=palette_color, autopct='%.0f%%')
#                                      ^
# SyntaxError: invalid syntax

# %%
df.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
 df.drop(df.columns[[0, 1, 2,4]], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13872/746466167.py in <module>
# ----> 1 df.drop(df.columns[[0, 1, 2,4]], axis=1, inplace=True)
#
# D:\MIT\ANACONDA\lib\site-packages\pandas\core\indexes\base.py in __getitem__(self, key)
#    4614             key = np.asarray(key, dtype=bool)
#    4615
# -> 4616         result = getitem(key)
#    4617         if not is_scalar(result):
#    4618             # error: Argument 1 to "ndim" has incompatible type "Union[ExtensionArray,
#
# IndexError: index 1 is out of bounds for axis 0 with size 1

# %%
df
# Out:
#      Annual Income (k$)
# 0                    15
# 1                    15
# 2                    16
# 3                    16
# 4                    17
# ..                  ...
# 195                 120
# 196                 126
# 197                 126
# 198                 137
# 199                 137
#
# [200 rows x 1 columns]

# %%
new_df = pd.read_csv('Mall_Customers.csv')

# %%
new_df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1       0   19                  15                      39
# 1             2       0   21                  15                      81
# 2             3       1   20                  16                       6
# 3             4       1   23                  16                      77
# 4             5       1   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196       1   35                 120                      79
# 196         197       1   45                 126                      28
# 197         198       0   32                 126                      74
# 198         199       0   32                 137                      18
# 199         200       0   30                 137                      83
#
# [200 rows x 5 columns]

# %%
df = new_df.drop(new_df.columns[[0,1,3,4]], axis=1)

# %%
p_df
# Out:
#      Age
# 0     19
# 1     21
# 2     20
# 3     23
# 4     31
# ..   ...
# 195   35
# 196   45
# 197   32
# 198   32
# 199   30
#
# [200 rows x 1 columns]

# %%
plt.pie(p_df, labels=df,autopct='%1.1f%%', shadow=True, startangle=140)
plt.title("age vs annual income distribution")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13872/1370286402.py in <module>
# ----> 1 plt.pie(p_df, labels=df,
#       2 autopct='%1.1f%%', shadow=True, startangle=140)
#       3 plt.title("age vs annual income distribution")
#       4 plt.show()
#
# D:\MIT\ANACONDA\lib\site-packages\matplotlib\pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, data)
#    3004         textprops=None, center=(0, 0), frame=False,
#    3005         rotatelabels=False, *, normalize=None, data=None):
# -> 3006     return gca().pie(
#    3007         x, explode=explode, labels=labels, colors=colors,
#    3008         autopct=autopct, pctdistance=pctdistance, shadow=shadow,
#
# ...

# %%
colors = sns.color_palette('pastel')[0:5]
plt.pie(p_df, labels = df, colors = colors)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13872/1100634203.py in <module>
#       1 colors = sns.color_palette('pastel')[0:5]
# ----> 2 plt.pie(p_df, labels = df, colors = colors)
#       3 plt.show()
#
# D:\MIT\ANACONDA\lib\site-packages\matplotlib\pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, data)
#    3004         textprops=None, center=(0, 0), frame=False,
#    3005         rotatelabels=False, *, normalize=None, data=None):
# -> 3006     return gca().pie(
#    3007         x, explode=explode, labels=labels, colors=colors,
#    3008         autopct=autopct, pctdistance=pctdistance, shadow=shadow,
#
# D:\MIT\ANACONDA\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
p_df
# Out:
#      Age
# 0     19
# 1     21
# 2     20
# 3     23
# 4     31
# ..   ...
# 195   35
# 196   45
# 197   32
# 198   32
# 199   30
#
# [200 rows x 1 columns]

# %%
df
# Out:
#      Annual Income (k$)
# 0                    15
# 1                    15
# 2                    16
# 3                    16
# 4                    17
# ..                  ...
# 195                 120
# 196                 126
# 197                 126
# 198                 137
# 199                 137
#
# [200 rows x 1 columns]

# %%
dff = np.array(df)

# %%
p_dfdf = np.array(p_df)

# %%
new_df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1       0   19                  15                      39
# 1             2       0   21                  15                      81
# 2             3       1   20                  16                       6
# 3             4       1   23                  16                      77
# 4             5       1   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196       1   35                 120                      79
# 196         197       1   45                 126                      28
# 197         198       0   32                 126                      74
# 198         199       0   32                 137                      18
# 199         200       0   30                 137                      83
#
# [200 rows x 5 columns]

# %%
annual_inc_data = new_df["Annual Income (k$)"]
age_data = new_df["Age"]
colors = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#8c564b"]

plt.pie(annual_inc_data, labels=age_data,  colors=colors,
autopct='%1.1f%%')
plt.title("Age-annual income distribution")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x = 'Annual Income (k$)',y = 'Spending Score (1-100)'  , hue="Gender",data = new_df  ,s = 60 )
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)') 
plt.title('Spending Score (1-100) vs Annual Income (k$)')
plt.legend()
plt.show()

# %%
age18_25 = df.Age[(df.Age <= 25) & (df.Age >= 18)]
age26_35 = df.Age[(df.Age <= 35) & (df.Age >= 26)]
age36_45 = df.Age[(df.Age <= 45) & (df.Age >= 36)]
age46_55 = df.Age[(df.Age <= 55) & (df.Age >= 46)]
age55above = df.Age[df.Age >= 56]

x = ["18-25","26-35","36-45","46-55","55+"]
y = [len(age18_25.values),len(age26_35.values),len(age36_45.values),len(age46_55.values),len(age55above.values)]

plt.figure(figsize=(10,6))
sns.barplot(x=x, y=y)
plt.title("Customer and Ages Barplot")
plt.xlabel("Age")
plt.ylabel("Number of Customers")
plt.show()

# %%
age18_25.value_counts().sum()
# Out:
# 38

# %%
spending_0-25 = new_df["SpendingScore(1-100)"][(new_df["SpendingScore(1-100)"] <= 25) & (new_df.SpendingScore(1-100) >= 0)]
soending_25-50 = new_df.SpendingScore(1-100)[(new_df.SpendingScore(1-100) <= 50) & (new_df.SpendingScore(1-100) >= 25)]
spending_50-75 = new_df.SpendingScore(1-100)[(df.SpendingScore(1-100) <= 75) & (df.SpendingScore(1-100) >= 50)]
spending_75-100 = df.SpendingScore(1-100)[(df.SpendingScore(1-100) <= 100) & (df.SpendingScore(1-100) >= 75)]


x = ["0-25","25-50","50-75","75-100"]
y = [len(spending_0-25.values),len(soending_25-50.values),len(spending_50-75.values),len(spending_75-100 .values)]

plt.figure(figsize=(10,6))
sns.barplot(x=x, y=y)
plt.title("Customer and spending score Barplot")
plt.xlabel("spending score")
plt.ylabel("Number of Customers")
plt.show()
# Out:
#   File "C:\Users\User\AppData\Local\Temp/ipykernel_13872/679656071.py", line 1
#     spending_0-25 = df.SpendingScore(1-100)[(df.SpendingScore(1-100) <= 25) & (df.SpendingScore(1-100) >= 0)]
#     ^
# SyntaxError: cannot assign to operator

# %%
new_df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1       0   19                  15                      39
# 1             2       0   21                  15                      81
# 2             3       1   20                  16                       6
# 3             4       1   23                  16                      77
# 4             5       1   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196       1   35                 120                      79
# 196         197       1   45                 126                      28
# 197         198       0   32                 126                      74
# 198         199       0   32                 137                      18
# 199         200       0   30                 137                      83
#
# [200 rows x 5 columns]

# %%
ss1_20 = new_df["Spending Score (1-100)"][(new_df["Spending Score (1-100)"] >= 0) & (new_df["Spending Score (1-100)"] <= 25)]
ss21_40 = new_df["Spending Score (1-100)"][(new_df["Spending Score (1-100)"] >= 26) & (new_df["Spending Score (1-100)"] <= 50)]
ss41_60 = new_df["Spending Score (1-100)"][(new_df["Spending Score (1-100)"] >= 51) & (new_df["Spending Score (1-100)"] <= 75)]
ss61_80 = new_df["Spending Score (1-100)"][(new_df["Spending Score (1-100)"] >= 76) & (new_df["Spending Score (1-100)"] <= 100)]

score_x = ["0-25", "26-50", "51-75", "76-100"]
score_y = [len(ss1_20.values), len(ss21_40.values), len(ss41_60.values), len(ss61_80.values)]

plt.figure(figsize=(10,6))
sns.barplot(x=score_x, y=score_y,palette="Set2")
plt.title("Spending Scores")
plt.xlabel("Score")
plt.ylabel("Number of Customer Having the Spending Score In That Range")
plt.show()

# %%
ai0_30 = new_df["Annual Income (k$)"][(new_df["Annual Income (k$)"] >= 0) & (new_df["Annual Income (k$)"] <= 30)]
ai31_60 = new_df["Annual Income (k$)"][(new_df["Annual Income (k$)"] >= 31) & (new_df["Annual Income (k$)"] <= 60)]
ai61_90 = new_df["Annual Income (k$)"][(new_df["Annual Income (k$)"] >= 61) & (new_df["Annual Income (k$)"] <= 90)]
ai91_120 = new_df["Annual Income (k$)"][(new_df["Annual Income (k$)"] >= 91) & (new_df["Annual Income (k$)"] <= 120)]
ai121_150 = new_df["Annual Income (k$)"][(new_df["Annual Income (k$)"] >= 121) & (new_df["Annual Income (k$)"] <= 150)]

income_x = ["$ 0 - 30,000", "$ 30,001 - 60,000", "$ 60,001 - 90,000", "$ 90,001 - 120,000", "$ 120,001 - 150,000"]
income_y = [len(ai0_30.values), len(ai31_60.values), len(ai61_90.values), len(ai91_120.values), len(ai121_150.values)]

plt.figure(figsize=(15,6))
sns.barplot(x=income_x, y=income_y, palette="nipy_spectral_r")
plt.title("Annual Incomes")
plt.xlabel("Income")
plt.ylabel("Number of Customer")
plt.show()

# %%
new_df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1       0   19                  15                      39
# 1             2       0   21                  15                      81
# 2             3       1   20                  16                       6
# 3             4       1   23                  16                      77
# 4             5       1   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196       1   35                 120                      79
# 196         197       1   45                 126                      28
# 197         198       0   32                 126                      74
# 198         199       0   32                 137                      18
# 199         200       0   30                 137                      83
#
# [200 rows x 5 columns]

# %%
i_df = new_df[["Annual Income (k$)","Spending Score (1-100)"]]

# %%
i_df
# Out:
#      Annual Income (k$)  Spending Score (1-100)
# 0                    15                      39
# 1                    15                      81
# 2                    16                       6
# 3                    16                      77
# 4                    17                      40
# ..                  ...                     ...
# 195                 120                      79
# 196                 126                      28
# 197                 126                      74
# 198                 137                      18
# 199                 137                      83
#
# [200 rows x 2 columns]

# %%
sns.scatterplot(x = "Annual Income (k$)", y = "Spending Score (1-100)", data = i_df)
plt.xlabel("Annual income of customers")
plt.ylabel("Spending scores of the customers")
plt.title("Correlation scatter plot")
# Out:
# Text(0.5, 1.0, 'Correlation scatter plot')

# %%
from sklearn.cluster import KMeans

# %%
wcss=[]

for i in range(1,11):
    km=KMeans(n_clusters=i)
    km.fit(i_df)
    wcss.append(km.inertia_)
# Out:
# D:\MIT\ANACONDA\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
plt.figure(figsize=(12,6))

plt.plot(range(1,11),wcss)

plt.plot(range(1,11),wcss, linewidth=2, color="red", marker ="8")

plt.xlabel("K Value")
plt.xticks(np.arange(1,11,1))
plt.ylabel("WCSS")

plt.show()
